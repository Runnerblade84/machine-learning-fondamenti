# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (16,10)
sns.set_theme(palette="dark")

# %%
BASE_URL = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/"
RANDOM_SEED = 1

# %%
df = pd.read_csv(BASE_URL+"mall_customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
X = df[["Age", "Annual Income (k$)"]].values

# %%
def plot_ssd_curve(data):
  
  ssd = {}
  for k in range(1, 10):
      kmeans = KMeans(init="k-means++", n_clusters=k, random_state=RANDOM_SEED, n_init="auto").fit(data)
      ssd[k] = kmeans.inertia_
  plt.figure()
  plt.plot(list(ssd.keys()), list(ssd.values()),marker='o')
  plt.xlabel("Numero di cluster", fontsize=16)
  plt.ylabel("Somma delle distanza al quadrato", fontsize=16)
  plt.show()

# %%
plot_ssd_curve(X)

# %%
X = df[["Annual Income (k$)", "Spending Score (1-100)", "Age"]].values

# %%
kmeans = KMeans(init="k-means++", n_clusters=5, random_state=RANDOM_SEED, n_init="auto").fit(X)

# %%
kmeans.cluster_centers_
# Out:
# array([[28.04      , 77.        , 24.96      ],
#        [26.30434783, 20.91304348, 45.2173913 ],
#        [55.21052632, 49.44736842, 43.93421053],
#        [87.43243243, 18.18918919, 40.32432432],
#        [86.53846154, 82.12820513, 32.69230769]])

# %%
kmeans.
# Out:
# <bound method BaseEstimator.get_params of KMeans(n_clusters=5, n_init='auto', random_state=1)>
